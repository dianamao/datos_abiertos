# %%
pip install sodapy
# Out:
# Collecting sodapy
#   Downloading sodapy-2.2.0-py2.py3-none-any.whl (15 kB)
# Collecting requests>=2.28.1 (from sodapy)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.28.1->sodapy)
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.28.1->sodapy)
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.5 kB ? eta -:--:--
#      ---------------------------------------- 61.5/61.5 kB 1.7 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests>=2.28.1->sodapy)
#   Downloading urllib3-2.0.7-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.28.1->sodapy)
#   Downloading certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 3.5 MB/s eta 0:00:00
# Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#    ---------------------------------------- 0.0/158.3 kB ? eta -:--:--
#    ---------------------------------------- 158.3/158.3 kB 9.9 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.9 kB ? eta -:--:--
#    ---------------------------------------- 99.9/99.9 kB ? eta 0:00:00
# Downloading urllib3-2.0.7-py3-none-any.whl (124 kB)
#    ---------------------------------------- 0.0/124.2 kB ? eta -:--:--
#    ---------------------------------------- 124.2/124.2 kB ? eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests, sodapy
# Successfully installed certifi-2023.7.22 charset-normalizer-3.3.2 idna-3.4 requests-2.31.0 sodapy-2.2.0 urllib3-2.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
indentificador_dataset = 'jbjy-vk9h'

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("www.datos.gov.co",
                 None)## Contraseña de ingreso a la plataforma de datos abiertos
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
socrata_dataset_identifier = "jbjy-vk9h"

Query = """
select 
    id_contrato, nombre_entidad, departamento, descripcion_del_proceso, valor_del_contrato
where
    fecha_de_firma >= '2022-06-01'
limit
1000
"""

contratos_2022 = client.get(socrata_dataset_identifier, content_type="json", query=Query)

secopII_2022_DF = pd.DataFrame(pd.DataFrame.from_dict(contratos_2022))
secopII_2022_DF
# Out:
#             id_contrato                                     nombre_entidad  \
# 0    CO1.PCCNTR.3721520                               MUNICIPIO DE LA CEJA
# 1    CO1.PCCNTR.3713062  SENA REGIONAL NORTE DE SANTANDER Grupo de Apoy...
# 2    CO1.PCCNTR.3707657  CORPORACIÓN AUTÓNOMA REGIONAL PARA LA DEFENSA ...
# 3    CO1.PCCNTR.3722023                               ICBF REGIONAL BOGOTA
# 4    CO1.PCCNTR.3719331         MUNICIPIO DE SAN JUAN BAUTISTA DE GUACARI2
# ..                  ...                                                ...
# 995  CO1.PCCNTR.3716105                 FUNDACION GILBERTO ALZATE AVENDAÑO
# 996  CO1.PCCNTR.3723086              ALCALDIA MUNICIPAL LA TEBAIDA QUINDIO
# 997  CO1.PCCNTR.3723383  UNIDAD ADMINISTRATIVA ESPECIAL DE REHABILITACI...
# 998  CO1.PCCNTR.3723189                                 MUNICIPIO DE PAIPA
# 999  CO1.PCCNTR.3721868                                  ALCALDIA DE MOCOA
#
#                    departamento  \
# 0                     Antioquia
# 1            Norte de Santander
# 2                     Santander
# 3    Distrito Capital de Bogotá
# 4               Valle del Cauca
# ..                          ...
# 995  Distrito Capital de Bogotá
# 996                     Quindío
# 997  Distrito Capital de Bogotá
# 998                      Boyacá
# 999                    Putumayo
#
#                                descripcion_del_proceso valor_del_contrato
# 0    PRESTACIÓN DE SERVICIOS DE FUMIGACIÓN Y MANEJO...            4345880
# 1    549119333 Contratar la compra de maquinaria y ...           87218194
# 2    CONTRATAR EL SUMINISTRO DE MAQUINARIA PESADA P...         3000000000
# 3    PRESTAR LOS SERVICIOS DE EDUCACIÓN INICIAL EN ...          379324558
# 4    Contratar los seguros que amparen los interese...           67938254
# ..                                                 ...                ...
# 995  Realizar los estudios y diseños requeridos par...          205458554
# 996  CONTRATO DE PRESTACIÓN DE SERVICIOS DE ACCESO ...           27987383
# 997  PRESTACIÓN DEL SERVICIO PARA LIMPIEZA Y RECOLE...            6037070
# 998  SUMINISTRO DE KITS EDUCATIVOS EN EL MARCO DEL ...           27806450
# 999  PRESTACION DE SERVICIOS DE APOYO LOGISTICO PAR...           22938000
#
# [1000 rows x 5 columns]
